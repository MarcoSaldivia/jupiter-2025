# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### **Carga de Dataset**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ruta = "/content/drive/MyDrive/Programacion/All_Pokemon.csv"

# %%
datos = pd.read_csv(ruta, index_col = "Number")

# %%
datos.head()
# Out:
#                  Name Type 1  Type 2                    Abilities  HP  Att  \
# Number
# 1           Bulbasaur  Grass  Poison  ['Chlorophyll', 'Overgrow']  45   49
# 2             Ivysaur  Grass  Poison  ['Chlorophyll', 'Overgrow']  60   62
# 3            Venusaur  Grass  Poison  ['Chlorophyll', 'Overgrow']  80   82
# 3       Mega Venusaur  Grass  Poison                ['Thick Fat']  80  100
# 4          Charmander   Fire     NaN     ['Blaze', 'Solar Power']  39   52
#
#         Def  Spa  Spd  Spe  ...  Against Bug  Against Rock  Against Ghost  \
# Number                      ...
# 1        49   65   65   45  ...          1.0           1.0            1.0
# 2        63   80   80   60  ...          1.0           1.0            1.0
# 3        83  100  100   80  ...          1.0           1.0            1.0
# 3       123  122  120   80  ...          1.0           1.0            1.0
# 4        43   60   50   65  ...          0.5           2.0            1.0
#
# ...

# %% [markdown]
# ### **A.-**

# %% [markdown]
# #### Mostrando informacion general

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1034 entries, 1 to 900
# Data columns (total 43 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Name                     1034 non-null   object
#  1   Type 1                   1034 non-null   object
#  2   Type 2                   549 non-null    object
#  3   Abilities                1034 non-null   object
#  4   HP                       1034 non-null   int64
#  5   Att                      1034 non-null   int64
#  6   Def                      1034 non-null   int64
#  7   Spa                      1034 non-null   int64
#  8   Spd                      1034 non-null   int64
#  9   Spe                      1034 non-null   int64
#  10  BST                      1034 non-null   int64
#  11  Mean                     1034 non-null   float64
#  12  Standard Deviation       1034 non-null   float64
#  13  Generation               1034 non-null   float64
# ...

# %%
datos.describe()
# Out:
#                 HP          Att          Def          Spa          Spd  \
# count  1034.000000  1034.000000  1034.000000  1034.000000  1034.000000
# mean     69.930368    80.544487    74.590909    72.908124    72.159574
# std      26.188367    32.514268    30.885981    32.764971    27.603097
# min       1.000000     5.000000     5.000000    10.000000    20.000000
# 25%      50.000000    55.250000    50.000000    50.000000    50.000000
# 50%      67.000000    78.000000    70.000000    65.000000    70.000000
# 75%      83.000000   100.000000    90.000000    95.000000    90.000000
# max     255.000000   190.000000   230.000000   194.000000   230.000000
#
#                Spe          BST         Mean  Standard Deviation   Generation  \
# count  1034.000000  1034.000000  1034.000000         1034.000000  1034.000000
# mean     68.609284   438.742747    73.123791           20.028863     4.431335
# std      30.225102   120.577842    20.096307           10.819824     2.265449
# ...

# %% [markdown]
# ### **B.-**

# %%
duplicados = datos.duplicated().sum()
if duplicados > 0:
    print(f"Se encontraron {duplicados} filas duplicadas. Procediendo a eliminarlas")
    datos.drop_duplicates(inplace=True)
else:
    print("No se encontraron filas duplicadas. No es necesario eliminarlas")

print("Dimensiones tras el paso de duplicados:", datos.shape)
# Out:
# Se encontraron 2 filas duplicadas. Procediendo a eliminarlas
# Dimensiones tras el paso de duplicados: (1032, 43)

# %% [markdown]
# ### **C.-**

# %% [markdown]
# #### Identificando las columnas con datos nulos

# %%
datos.isnull()
# Out:
#          Name  Type 1  Type 2  Abilities     HP    Att    Def    Spa    Spd  \
# Number
# 1       False   False   False      False  False  False  False  False  False
# 2       False   False   False      False  False  False  False  False  False
# 3       False   False   False      False  False  False  False  False  False
# 3       False   False   False      False  False  False  False  False  False
# 4       False   False    True      False  False  False  False  False  False
# ...       ...     ...     ...        ...    ...    ...    ...    ...    ...
# 896     False   False    True      False  False  False  False  False  False
# 897     False   False    True      False  False  False  False  False  False
# 898     False   False   False      False  False  False  False  False  False
# 898     False   False   False      False  False  False  False  False  False
# 898     False   False   False      False  False  False  False  False  False
#
# ...

# %%
columnas_nulas = datos.isnull().any()
columnas_nulas
# Out:
# Name                       False
# Type 1                     False
# Type 2                      True
# Abilities                  False
# HP                         False
# Att                        False
# Def                        False
# Spa                        False
# Spd                        False
# Spe                        False
# BST                        False
# Mean                       False
# Standard Deviation         False
# Generation                 False
# Experience type            False
# Experience to level 100    False
# Final Evolution            False
# Catch Rate                 False
# Legendary                  False
# Mega Evolution             False
# Alolan Form                False
# Galarian Form              False
# Against Normal             False
# Against Fire               False
# Against Water              False
# Against Electric           False
# Against Grass              False
# Against Ice                False
# ...

# %% [markdown]
# #### Eliminar los datos nulos

# %%
datos_sin_nulos = datos.dropna()

# %% [markdown]
# #### Mostrando nuevo data set sin nulos

# %%
datos_sin_nulos
# Out:
#                                Name    Type 1  Type 2  \
# Number
# 1                         Bulbasaur     Grass  Poison
# 2                           Ivysaur     Grass  Poison
# 3                          Venusaur     Grass  Poison
# 3                     Mega Venusaur     Grass  Poison
# 6                         Charizard      Fire  Flying
# ...                             ...       ...     ...
# 892     Urshifu Single Strike Style  Fighting    Dark
# 893                          Zarude      Dark   Grass
# 898                         Calyrex   Psychic   Grass
# 898               Calyrex Ice Rider   Psychic     Ice
# 898            Calyrex Shadow Rider   Psychic   Ghost
#
#                           Abilities   HP  Att  Def  Spa  Spd  Spe  ...  \
# Number                                                             ...
# 1       ['Chlorophyll', 'Overgrow']   45   49   49   65   65   45  ...
# 2       ['Chlorophyll', 'Overgrow']   60   62   63   80   80   60  ...
# ...

# %% [markdown]
# ### **D.-**

# %% [markdown]
# #### Funcion para filtrar los primeros 20 Pokemon tipo fuego

# %%
def filtro_fuego(type):
    return 'Fire' in type

datosfuego = datos[datos['Type 1'].apply(filtro_fuego)]

nombresfuego = datosfuego[['Name', 'Type 1']]
nombresfuego.head(20)
# Out:
#                     Name Type 1
# Number
# 4             Charmander   Fire
# 5             Charmeleon   Fire
# 6              Charizard   Fire
# 6       Mega Charizard Y   Fire
# 6       Mega Charizard X   Fire
# 37                Vulpix   Fire
# 38             Ninetales   Fire
# 58             Growlithe   Fire
# 59              Arcanine   Fire
# 77                Ponyta   Fire
# 78              Rapidash   Fire
# 105       Alolan Marowak   Fire
# 126               Magmar   Fire
# 136              Flareon   Fire
# 146              Moltres   Fire
# 155            Cyndaquil   Fire
# 156              Quilava   Fire
# 157           Typhlosion   Fire
# 218               Slugma   Fire
# 219             Magcargo   Fire

# %% [markdown]
# ### **E.-**

# %% [markdown]
# #### Obtener el promedio del Nivel de Defensa

# %%
promediofuego = datosfuego[['Def']]
promDef = promediofuego.mean()

# %%
promDef
# Out:
# Def    68.078125
# dtype: float64

# %% [markdown]
# ### **F.-**

# %% [markdown]
# #### Grafico de Barra

# %%
graficofuego = nombresfuego.head(10)

graficofuego.set_index('Name', inplace=True)
graph = graficofuego['Att´'].plot(kind='bar')

for i, rating in enumerate(graficofuego['Att']):
    graph.annotate(str(att), xy=(i, att), ha='center', va='bottom')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-84-2628011270.py in <cell line: 0>()
#       2
#       3 graficofuego.set_index('Name', inplace=True)
# ----> 4 graph = graficofuego[Att].plot(kind='bar')
#       5
#       6 for i, rating in enumerate(graficofuego['Att']):
#
# NameError: name 'Att' is not defined

# %% [markdown]
# #### Grafico de linea

# %%
plt.plot(nombresfuego, label = "Pokemon")
plt.title("Grafico del Pokemon")
plt.xlabel("Posicion")
plt.ylabel("Valores")
plt.grid(True)
plt.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-81-575478847.py in <cell line: 0>()
# ----> 1 plt.plot(nombresfuego, label = "Pokemon")
#       2 plt.title("Grafico del Pokemon")
#       3 plt.xlabel("Indice (Posicion)")
#       4 plt.ylabel("Valores")
#       5 plt.grid(True)
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3827     **kwargs,
#    3828 ) -> list[Line2D]:
# -> 3829     return gca().plot(
#    3830         *args,
#    3831         scalex=scalex,
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1775         """
#    1776         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1777         lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1778         for line in lines:
# ...
